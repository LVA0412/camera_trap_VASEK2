# %% [markdown]
# <a href="https://colab.research.google.com/github/LVA0412/camera_trap_VASEK2/blob/main/read_and_%20explore_json_file.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json

# Открытие файла для чтения
with open('/content/test_output (1).json', 'r') as file:
    # Parse JSON data
    data = json.load(file)

# Display the data
print(data)
# Out:
# {'images': [{'file': 'clear_100__PICT0351.JPG', 'detections': [{'category': '1', 'conf': 0.00505, 'bbox': [0.5754, 0, 0.0305, 0.05]}, {'category': '1', 'conf': 0.00582, 'bbox': [0.3844, 0.05466, 0.01999, 0.02566]}, {'category': '1', 'conf': 0.0106, 'bbox': [0.4464, 0.05933, 0.04899, 0.02333]}, {'category': '1', 'conf': 0.0372, 'bbox': [0.3859, 0.05033, 0.0195, 0.01799]}, {'category': '1', 'conf': 0.939, 'bbox': [0.4592, 0.2283, 0.08874, 0.164]}, {'category': '1', 'conf': 0.942, 'bbox': [0.7124, 0.3139, 0.05225, 0.2793]}, {'category': '1', 'conf': 0.945, 'bbox': [0.9267, 0.2423, 0.07325, 0.2226]}, {'category': '1', 'conf': 0.946, 'bbox': [0.7664, 0.262, 0.09075, 0.1856]}, {'category': '1', 'conf': 0.948, 'bbox': [0.8262, 0.2269, 0.1057, 0.2099]}, {'category': '1', 'conf': 0.949, 'bbox': [0.5125, 0.3443, 0.1519, 0.2549]}, {'category': '1', 'conf': 0.962, 'bbox': [0.3102, 0.2073, 0.1414, 0.229]}]}, {'file': 'clear_101__три_лосихи_март_PICT0168.jpg', 'detections': [{'category': '1', 'conf': 0.902, 'bbox': [0.1329, 0.453, 0.1316, 0.16]}, {'category': '1', 'conf': 0.951, 'bbox': [0.5086, 0.4735, 0.1522, 0.2953]}, {'category': '1', 'conf': 0.968, 'bbox': [0.6842, 0.5449, 0.1733, 0.3568]}]}, {'file': 'clear_102__марал_с_мал_пантами.jpg', 'detections': [{'category': '1', 'conf': 0.976, 'bbox': [0.049, 0.4839, 0.2307, 0.3713]}]}, {'file': 'clear_103__лабаз.jpg', 'detections': [{'category': '1', 'conf': 0.00846, 'bbox': [0.8882, 0.793, 0.1115, 0.1716]}, {'category': '1', 'conf': 0.0589, 'bbox': [0, 0.7236, 0.05649, 0.2426]}]}, {'file': 'clear_104__PICT0421.JPG', 'detections': [{'category': '1', 'conf': 0.00723, 'bbox': [0.1462, 0.5363, 0.01724, 0.03866]}, {'category': '1', 'conf': 0.00874, 'bbox': [0.1052, 0.8369, 0.8947, 0.1276]}, {'category': '1', 'conf': 0.0178, 'bbox': [0.9654, 0.544, 0.03325, 0.017]}, {'category': '1', 'conf': 0.788, 'bbox': [0.05124, 0.6816, 0.04825, 0.05633]}]}, {'file': 'clear_105__белая_ночь.JPG', 'detections': [{'category': '1', 'conf': 0.00732, 'bbox': [0.7017, 0.6699, 0.1112, 0.2473]}, {'category': '1', 'conf': 0.0341, 'bbox': [0, 0.3916, 0.03449, 0.206]}, {'category': '1', 'conf': 0.73, 'bbox': [0.6922, 0.3086, 0.1254, 0.333]}, {'category': '1', 'conf': 0.857, 'bbox': [0.5389, 0.2719, 0.09149, 0.1749]}]}, {'file': 'clear_106__PICT0304.JPG', 'detections': [{'category': '1', 'conf': 0.00797, 'bbox': [0.6067, 0.541, 0.06774, 0.041]}, {'category': '1', 'conf': 0.0135, 'bbox': [0.5004, 0.3483, 0.039, 0.02133]}, {'category': '1', 'conf': 0.0578, 'bbox': [0.7294, 0.3486, 0.0185, 0.01133]}, {'category': '1', 'conf': 0.928, 'bbox': [0.308, 0.4356, 0.05725, 0.1203]}, {'category': '1', 'conf': 0.954, 'bbox': [0.2082, 0.477, 0.1367, 0.1856]}, {'category': '1', 'conf': 0.962, 'bbox': [0.1175, 0.4163, 0.07824, 0.206]}, {'category': '1', 'conf': 0.972, 'bbox': [0.7862, 0.547, 0.1547, 0.3433]}, {'category': '1', 'conf': 0.978, 'bbox': [0.4997, 0.544, 0.2772, 0.3293]}]}, {'file': 'clear_107__косуля_м_взр.jpg', 'detections': [{'category': '1', 'conf': 0.921, 'bbox': [0.6342, 0.496, 0.1371, 0.1188]}, {'category': '1', 'conf': 0.958, 'bbox': [0.2955, 0.5385, 0.2356, 0.2573]}]}, {'file': 'clear_108__маралуха_в_профиль.jpg', 'detections': [{'category': '1', 'conf': 0.98, 'bbox': [0.5562, 0.4076, 0.303, 0.4433]}]}, {'file': 'clear_109__SY000034.JPG', 'detections': [{'category': '1', 'conf': 0.0343, 'bbox': [0.8627, 0.6003, 0.1362, 0.2756]}, {'category': '1', 'conf': 0.0487, 'bbox': [0.8637, 0.7466, 0.1337, 0.1236]}, {'category': '1', 'conf': 0.0908, 'bbox': [0.8627, 0.7569, 0.05074, 0.1129]}, {'category': '1', 'conf': 0.973, 'bbox': [0.5417, 0.4239, 0.4569, 0.5566]}]}, {'file': 'clear_110__PICT1644.JPG', 'detections': [{'category': '1', 'conf': 0.951, 'bbox': [0.4072, 0.277, 0.2907, 0.4269]}, {'category': '1', 'conf': 0.969, 'bbox': [0.7622, 0.3233, 0.2377, 0.4253]}]}, {'file': 'clear_111__PICT0237_маралушки.jpg', 'detections': [{'category': '1', 'conf': 0.944, 'bbox': [0.5742, 0.492, 0.1187, 0.221]}, {'category': '1', 'conf': 0.9 ...

# %%
import numpy as np
import pandas as pd

# %%
# использование данных
animals = data['images']
list_1=[]
# перебор файлов
for animal in animals:
    list_1.append(animal['file'])
ser=pd.Series(list_1)

# %%
# использование данных
animals = data['images']
list_2=[]
i=0
a=0
# перебор файлов для извлечения нужной категории и уверенности
for animal in animals:

        for i in range(len(animal['detections'])):

            kategoria=(animal['detections'][i]['category'])
            uverennost= (animal['detections'][i]['conf'])
            if int(kategoria)==1 and float(uverennost)>0.7:

                a+=1
            i+=1
        if a:
          c=1
          list_2.append(1)
        else: list_2.append(0)

# %%
with_animals=pd.DataFrame({'file':list_1, 'animal':list_2})
with_animals
# Out:
#                                         file  animal
# 0                    clear_100__PICT0351.JPG       1
# 1    clear_101__три_лосихи_март_PICT0168.jpg       1
# 2         clear_102__марал_с_мал_пантами.jpg       1
# 3                       clear_103__лабаз.jpg       1
# 4                    clear_104__PICT0421.JPG       1
# ..                                       ...     ...
# 314                   clear_95__PICT0678.JPG       1
# 315                   clear_96__PICT0123.JPG       1
# 316  clear_97__убегающие_косули_PICT0557.jpg       1
# 317                   clear_98__PICT0158.JPG       1
# 318  clear_99__марал_и_маралуха_PICT0124.jpg       1
#
# [319 rows x 2 columns]

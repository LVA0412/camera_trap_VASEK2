# %% [markdown]
# <a href="https://colab.research.google.com/github/LVA0412/camera_trap_VASEK2/blob/main/read_and_explore_json_file_ver2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json

# Открытие файла для чтения

from google.colab import drive
drive.mount('/content/drive')

with open('/content/drive/My Drive/train_dataset_altai/train_dataset_altai_results.json', 'r') as file:
    # Parse JSON data
    data = json.load(file)

# Display the data
print(data)
# Out:
# Mounted at /content/drive
# {'images': [{'file': 'broken_imgs/PICT0082.JPG', 'detections': []}, {'file': 'clear_imgs/clear_100__PICT0351.JPG', 'detections': [{'category': '1', 'conf': 0.00895, 'bbox': [0.4464, 0.06, 0.04899, 0.02266]}, {'category': '1', 'conf': 0.0311, 'bbox': [0.3859, 0.05066, 0.0195, 0.01733]}, {'category': '1', 'conf': 0.939, 'bbox': [0.46, 0.2283, 0.08824, 0.164]}, {'category': '1', 'conf': 0.942, 'bbox': [0.7124, 0.3139, 0.05225, 0.2793]}, {'category': '1', 'conf': 0.945, 'bbox': [0.9267, 0.2423, 0.07325, 0.2226]}, {'category': '1', 'conf': 0.946, 'bbox': [0.7664, 0.262, 0.09075, 0.1856]}, {'category': '1', 'conf': 0.949, 'bbox': [0.5124, 0.3443, 0.1517, 0.2549]}, {'category': '1', 'conf': 0.949, 'bbox': [0.8262, 0.227, 0.1057, 0.2103]}, {'category': '1', 'conf': 0.962, 'bbox': [0.3102, 0.2073, 0.1414, 0.2286]}]}, {'file': 'clear_imgs/clear_101__три_лосихи_март_PICT0168.jpg', 'detections': [{'category': '1', 'conf': 0.902, 'bbox': [0.1326, 0.453, 0.1319, 0.16]}, {'category': '1', 'conf': 0.951, 'bbox': [0.5086, 0.4735, 0.1522, 0.2953]}, {'category': '1', 'conf': 0.968, 'bbox': [0.6842, 0.5449, 0.1733, 0.3568]}]}, {'file': 'clear_imgs/clear_102__марал_с_мал_пантами.jpg', 'detections': [{'category': '1', 'conf': 0.976, 'bbox': [0.049, 0.4839, 0.2307, 0.3713]}]}, {'file': 'clear_imgs/clear_103__лабаз.jpg', 'detections': [{'category': '1', 'conf': 0.00768, 'bbox': [0.8882, 0.793, 0.1115, 0.1716]}, {'category': '1', 'conf': 0.0569, 'bbox': [0, 0.724, 0.05674, 0.2423]}]}, {'file': 'clear_imgs/clear_104__PICT0421.JPG', 'detections': [{'category': '1', 'conf': 0.00728, 'bbox': [0.1462, 0.5363, 0.01724, 0.03866]}, {'category': '1', 'conf': 0.00879, 'bbox': [0.07725, 0.8349, 0.9227, 0.1283]}, {'category': '1', 'conf': 0.0193, 'bbox': [0.9654, 0.544, 0.03325, 0.017]}, {'category': '1', 'conf': 0.803, 'bbox': [0.05149, 0.6816, 0.048, 0.05633]}]}, {'file': 'clear_imgs/clear_105__белая_ночь.JPG', 'detections': [{'category': '1', 'conf': 0.00751, 'bbox': [0.7017, 0.6703, 0.1112, 0.2463]}, {'category': '1', 'conf': 0.0363, 'bbox': [0, 0.3916, 0.03449, 0.206]}, {'category': '1', 'conf': 0.731, 'bbox': [0.6919, 0.3076, 0.126, 0.3356]}, {'category': '1', 'conf': 0.86, 'bbox': [0.5392, 0.2716, 0.09125, 0.1753]}]}, {'file': 'clear_imgs/clear_106__PICT0304.JPG', 'detections': [{'category': '1', 'conf': 0.0072, 'bbox': [0.6067, 0.541, 0.06774, 0.041]}, {'category': '1', 'conf': 0.0123, 'bbox': [0.5002, 0.3483, 0.03925, 0.02166]}, {'category': '1', 'conf': 0.0585, 'bbox': [0.7294, 0.3486, 0.0185, 0.01133]}, {'category': '1', 'conf': 0.928, 'bbox': [0.308, 0.4359, 0.0575, 0.1199]}, {'category': '1', 'conf': 0.954, 'bbox': [0.2082, 0.477, 0.1365, 0.1856]}, {'category': '1', 'conf': 0.962, 'bbox': [0.1175, 0.4163, 0.07824, 0.206]}, {'category': '1', 'conf': 0.972, 'bbox': [0.7862, 0.547, 0.1547, 0.3433]}, {'category': '1', 'conf': 0.978, 'bbox': [0.4997, 0.544, 0.2772, 0.3293]}]}, {'file': 'clear_imgs/clear_107__косуля_м_взр.jpg', 'detections': [{'category': '1', 'conf': 0.919, 'bbox': [0.6342, 0.496, 0.1371, 0.1188]}, {'category': '1', 'conf': 0.957, 'bbox': [0.2955, 0.5385, 0.2356, 0.2573]}]}, {'file': 'clear_imgs/clear_108__маралуха_в_профиль.jpg', 'detections': [{'category': '1', 'conf': 0.98, 'bbox': [0.5562, 0.4076, 0.303, 0.4433]}]}, {'file': 'clear_imgs/clear_109__SY000034.JPG', 'detections': [{'category': '1', 'conf': 0.0335, 'bbox': [0.8627, 0.601, 0.1362, 0.2743]}, {'category': '1', 'conf': 0.048, 'bbox': [0.8637, 0.7463, 0.1334, 0.1236]}, {'category': '1', 'conf': 0.0882, 'bbox': [0.8627, 0.7569, 0.05074, 0.1129]}, {'category': '1', 'conf': 0.973, 'bbox': [0.5417, 0.4239, 0.4569, 0.5566]}]}, {'file': 'clear_imgs/clear_110__PICT1644.JPG', 'detections': [{'category': '1', 'conf': 0.952, 'bbox': [0.4072, 0.2773, 0.2907, 0.4269]}, {'category': '1', 'conf': 0.969, 'bbox': [0.7622, 0.3233, 0.2377, 0.4256]}]}, {'file': 'clear_imgs/clear_111__PICT0237_маралушки.jpg', 'detections': [{'category': '1', 'conf': 0.945, 'bbox': [0.5742, 0.4919, 0.1187, 0.2216]} ...

# %%
import numpy as np
import pandas as pd

# %%
# использование данных
animals = data['images']
list_1=[]
# перебор файлов
for animal in animals:
    list_1.append(animal['file'])
ser=pd.Series(list_1)

# %%
# использование данных
animals = data['images']
list_2=[]
list_3=[]
list_4=[]
i=0
a=0
# перебор файлов для извлечения нужной категории и уверенности
for animal in animals:

        for i in range(len(animal['detections'])):

            kategoria=(animal['detections'][i]['category'])
            uverennost= (animal['detections'][i]['conf'])
            if int(kategoria)==1 and float(uverennost)>0.7:

                a+=1
            i+=1
        if a:
          list_2.append(0), list_3.append(0), list_4.append(1)
        else: list_2.append(0), list_3.append(0), list_4.append(0)

# %%
with_animals=pd.DataFrame({'filename':list_1, 'broken':list_2, 'empty':list_3, 'animal':list_4})
with_animals
# Out:
#                                                filename  broken  empty  animal
# 0                              broken_imgs/PICT0082.JPG       0      0       0
# 1                    clear_imgs/clear_100__PICT0351.JPG       0      0       1
# 2     clear_imgs/clear_101__три_лосихи_март_PICT0168...       0      0       1
# 3         clear_imgs/clear_102__марал_с_мал_пантами.jpg       0      0       1
# 4                       clear_imgs/clear_103__лабаз.jpg       0      0       1
# ...                                                 ...     ...    ...     ...
# 4312  фотоловушка новое/flхатка20160929/102EK113/PIC...       0      0       1
# 4313  фотоловушка новое/flхатка20160929/102EK113/PIC...       0      0       1
# 4314  фотоловушка новое/flхатка20160929/102EK113/PIC...       0      0       1
# 4315  фотоловушка новое/flхатка20160929/102EK113/PIC...       0      0       1
# 4316  фотоловушка новое/flхатка20160929/102EK113/PIC...       0      0       1
#
# [4317 rows x 4 columns]

# %%
#Экспорт csv
with_animals.to_csv('/content/drive/My Drive/train_dataset_altai/result.csv')
